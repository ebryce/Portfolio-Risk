# %%
# System libraries
import sys, os, gc
import datetime

# Math libraries
import math, random
import pandas as pd, numpy as np
import scipy
from scipy import stats
from datetime import timedelta
from datetime import datetime
import itertools

# Data storage libraries
import pickle, sqlite3, simpledbf, boto3

# Custom financial data libraries
import findata_utils as fd
import ml_utils

# Plotting libraries
import matplotlib.pyplot as plt
from matplotlib import rcParams

import warnings
#if not sys.warnoptions:
#    warnings.simplefilter("ignore")

from importlib import reload
fd = reload(fd)

import sklearn as sk
import tensorflow as tf
import xgboost as xgb
import keras

from imblearn.over_sampling import RandomOverSampler

from sklearn import svm
from sklearn import preprocessing
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.linear_model import ElasticNet, LogisticRegression
from sklearn.metrics import explained_variance_score, mean_squared_error, confusion_matrix, classification_report, accuracy_score
from sklearn.model_selection import cross_val_score, KFold, GridSearchCV
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.pipeline import Pipeline
from sklearn.externals import joblib 

from keras.models import Sequential
from keras.optimizers import SGD
from keras.layers import Dense, Dropout
from keras.wrappers.scikit_learn import KerasRegressor

from yellowbrick.regressor import ResidualsPlot, PredictionError

# Connect to databases
db = 'C:\\Datasets\\thesis.db'
overleaf = ['C:','Users','bryce','OneDrive','Documents','Overleaf','5babbfe264c952737a9a5117','esc499']
conn = sqlite3.connect(db)
c = conn.cursor()

hdf_path = 'C:\\Datasets\\thesis.h5'
hdf = pd.HDFStore(hdf_path)

# %%
index = 'S&P/TSX Composite Index'

holdings = pd.read_sql('''
    SELECT * FROM index_holdings_2019
    WHERE [index]='{Index}'
    LIMIT 100'''.format(Index=index),
           conn)
print(holdings.head())

changes = pd.read_sql('''
    SELECT *
    FROM factset_index_changes
    WHERE [index]='{Index}'
    LIMIT 100'''.format(Index=index),
           conn)
print()
print(changes.head())

tickers = np.concatenate([holdings['ticker'].unique(), changes['ticker'].unique()])
print()
print(tickers)
# Out:
#   ticker exchange                    index
# 0    ABX      TSX  S&P/TSX Composite Index
# 1     AC      TSX  S&P/TSX Composite Index
# 2    ACB      TSX  S&P/TSX Composite Index
# 3  ACO.X      TSX  S&P/TSX Composite Index
# 4     AD      TSX  S&P/TSX Composite Index
#
#                   date action                    index exchange  ticker  \
# 0  2019-03-18 00:00:00    Add  S&P/TSX Composite Index      TSX  SMU.UN
# 1  2019-03-18 00:00:00    Add  S&P/TSX Composite Index      TSX     CJT
# 2  2019-03-18 00:00:00    Add  S&P/TSX Composite Index      TSX  DIR.UN
# 3  2019-03-18 00:00:00    Add  S&P/TSX Composite Index      TSX     AFN
# 4  2019-03-18 00:00:00    Add  S&P/TSX Composite Index      TSX  NWH.UN
#
#                                                 name
# 0                     Summit Industrial Income REIT
# 1                                     Cargojet Inc.
# 2     Dream Industrial Real Estate Investment Trust
# 3                      Ag Growth International Inc.
# 4  NorthWest Healthcare Properties Real Estate In...
#
# ['ABX' 'AC' 'ACB' 'ACO.X' 'AD' 'AEM' 'AFN' 'AGI' 'AIF' 'ALA' 'AP.UN'
#  'APHA' 'AQN' 'ARE' 'ARX' 'ASR' 'ATA' 'ATD.B' 'ATZ' 'AX.UN' 'BAD' 'BAM.A'
#  'BB' 'BBD.B' 'BBU.UN' 'BCB' 'BCE' 'BEI.UN' 'BEP.UN' 'BHC' 'BIP.UN' 'BIR'
#  'BLX' 'BMO' 'BNS' 'BPY.UN' 'BTE' 'BTO' 'BYD.UN' 'CAE' 'CAR.UN' 'CAS'
#  'CCA' 'CCL.B' 'CCO' 'CEU' 'CFP' 'CG' 'CGX' 'CHE.UN' 'CHP.UN' 'CHR' 'CIGI'
#  'CIX' 'CJT' 'CLS' 'CM' 'CNQ' 'CNR' 'CP' 'CPG' 'CPX' 'CRON' 'CRR.UN'
#  'CSH.UN' 'CSU' 'CTC.A' 'CU' 'CUF.UN' 'CVE' 'CWB' 'D.UN' 'DGC' 'DIR.UN'
#  'DOL' 'DOO' 'DRG.UN' 'DSG' 'ECA' 'ECN' 'EDV' 'EFN' 'EFX' 'EIF' 'ELD'
#  'EMA' 'EMP.A' 'ENB' 'ENGH' 'ERF' 'ERO' 'ESI' 'EXE' 'FCR' 'FFH' 'FM' 'FNV'
#  'FR' 'FRU' 'FSV' 'SMU.UN' 'CJT' 'DIR.UN' 'AFN' 'NWH.UN' 'ERO' 'CMG' 'KML'
#  'LUC' 'NSU' 'MAXR' 'ATZ' 'POU' 'TVE' 'TCW' 'AAV' 'GUY' 'DII.B' 'ENF'
#  'MTY' 'IIP.UN' 'CJR.B' 'RCH' 'RRX' 'PLI' 'CHP.UN' 'SIA' 'ACB' 'CR' 'CHR'
#  'APHA' 'KMP.UN' 'GOOS' 'JE' 'BNP']

# %%
all_mkt_cap = pd.read_sql('''
    SELECT c.ticker, c.date, COALESCE(s.shares_out,0)*COALESCE(c.c,0) AS mkt_cap
    FROM cfmrc c
    LEFT JOIN shares_out s
        ON c.ticker=s.ticker
    WHERE mkt_cap>0''', conn)

print(all_mkt_cap.head())
# Out:
#   ticker        date       mkt_cap
# 0    AAV  2010-01-04  1.318031e+09
# 1    AAV  2010-01-05  1.373801e+09
# 2    AAV  2010-01-06  1.399827e+09
# 3    AAV  2010-01-07  1.366365e+09
# 4    AAV  2010-01-08  1.401686e+09

# %%
# Out:
#                    date  action                    index exchange  ticker  \
# 0   2019-03-18 00:00:00     Add  S&P/TSX Composite Index      TSX  SMU.UN
# 1   2019-03-18 00:00:00     Add  S&P/TSX Composite Index      TSX     CJT
# 2   2019-03-18 00:00:00     Add  S&P/TSX Composite Index      TSX  DIR.UN
# 3   2019-03-18 00:00:00     Add  S&P/TSX Composite Index      TSX     AFN
# 4   2019-03-18 00:00:00     Add  S&P/TSX Composite Index      TSX  NWH.UN
# 5   2019-03-18 00:00:00     Add  S&P/TSX Composite Index      TSX     ERO
# 6   2019-03-18 00:00:00  Delete  S&P/TSX Composite Index      TSX     CMG
# 7   2019-03-18 00:00:00  Delete  S&P/TSX Composite Index      TSX     KML
# 8   2019-03-18 00:00:00  Delete  S&P/TSX Composite Index      TSX     LUC
# 9   2019-03-18 00:00:00     Add  S&P/TSX Composite Index      TSX  SMU.UN
# 10  2019-03-18 00:00:00     Add  S&P/TSX Composite Index      TSX     CJT
# 11  2019-03-18 00:00:00     Add  S&P/TSX Composite Index      TSX  DIR.UN
# 12  2019-03-18 00:00:00     Add  S&P/TSX Composite Index      TSX     AFN
# 13  2019-03-18 00:00:00     Add  S&P/TSX Composite Index      TSX  NWH.UN
# 14  2019-03-18 00:00:00     Add  S&P/TSX Composite Index      TSX     ERO
# 15  2019-03-18 00:00:00     Add  S&P/TSX Composite Index      TSX  SMU.UN
# 16  2019-03-18 00:00:00     Add  S&P/TSX Composite Index      TSX     CJT
# 17  2019-03-18 00:00:00     Add  S&P/TSX Composite Index      TSX  DIR.UN
# 18  2019-03-18 00:00:00     Add  S&P/TSX Composite Index      TSX     AFN
# 19  2019-03-18 00:00:00     Add  S&P/TSX Composite Index      TSX  NWH.UN
# 20  2019-03-18 00:00:00     Add  S&P/TSX Composite Index      TSX     ERO
# 21  2019-03-18 00:00:00     Add  S&P/TSX Composite Index      TSX  SMU.UN
# 22  2019-03-18 00:00:00     Add  S&P/TSX Composite Index      TSX     CJT
# 23  2019-03-18 00:00:00     Add  S&P/TSX Composite Index      TSX  DIR.UN
# 24  2019-03-18 00:00:00     Add  S&P/TSX Composite Index      TSX     AFN
# 25  2019-03-18 00:00:00     Add  S&P/TSX Composite Index      TSX  NWH.UN
# 26  2019-03-18 00:00:00     Add  S&P/TSX Composite Index      TSX     ERO
# 27  2019-03-18 00:00:00     Add  S&P/TSX Composite Index      TSX  SMU.UN
# 28  2019-03-18 00:00:00     Add  S&P/TSX Composite Index      TSX     CJT
# 29  2019-03-18 00:00:00     Add  S&P/TSX Composite Index      TSX  DIR.UN
# ..                  ...     ...                      ...      ...     ...
# 70  2018-12-24 00:00:00  Delete  S&P/TSX Composite Index      TSX     GUY
# 71  2018-12-24 00:00:00  Delete  S&P/TSX Composite Index      TSX   DII.B
# 72  2018-12-24 00:00:00     Add  S&P/TSX Composite Index      TSX     ATZ
# 73  2018-12-24 00:00:00     Add  S&P/TSX Composite Index      TSX     ATZ
# 74  2018-12-24 00:00:00     Add  S&P/TSX Composite Index      TSX     ATZ
# 75  2018-12-24 00:00:00     Add  S&P/TSX Composite Index      TSX     ATZ
# 76  2018-12-24 00:00:00     Add  S&P/TSX Composite Index      TSX     ATZ
# 77  2018-12-24 00:00:00     Add  S&P/TSX Composite Index      TSX     ATZ
# 78  2018-12-24 00:00:00     Add  S&P/TSX Composite Index      TSX     ATZ
# 79  2018-12-24 00:00:00     Add  S&P/TSX Composite Index      TSX     ATZ
# 80  2018-12-24 00:00:00     Add  S&P/TSX Composite Index      TSX     ATZ
# 81  2018-11-12 00:00:00  Delete  S&P/TSX Composite Index      TSX     ENF
# 82  2018-09-24 00:00:00     Add  S&P/TSX Composite Index      TSX     TVE
# 83  2018-09-24 00:00:00     Add  S&P/TSX Composite Index      TSX     MTY
# 84  2018-09-24 00:00:00     Add  S&P/TSX Composite Index      TSX  IIP.UN
# 85  2018-09-24 00:00:00  Delete  S&P/TSX Composite Index      TSX   CJR.B
# 86  2018-09-24 00:00:00     Add  S&P/TSX Composite Index      TSX     RCH
# 87  2018-08-28 00:00:00  Delete  S&P/TSX Composite Index      TSX     RRX
# 88  2018-06-18 00:00:00  Delete  S&P/TSX Composite Index      TSX     PLI
# 89  2018-05-08 00:00:00     Add  S&P/TSX Composite Index      TSX  CHP.UN
# 90  2018-03-19 00:00:00     Add  S&P/TSX Composite Index      TSX     SIA
# 91  2018-03-19 00:00:00     Add  S&P/TSX Composite Index      TSX     ACB
# 92  2018-03-19 00:00:00  Delete  S&P/TSX Composite Index      TSX      CR
# 93  2017-12-18 00:00:00     Add  S&P/TSX Composite Index      TSX     CHR
# 94  2017-12-18 00:00:00     Add  S&P/TSX Composite Index      TSX    APHA
# 95  2017-12-18 00:00:00     Add  S&P/TSX Composite Index      TSX  KMP.UN
# 96  2017-12-18 00:00:00     Add  S&P/TSX Composite Index      TSX    GOOS
# 97  2017-12-18 00:00:00     Add  S&P/TSX Composite Index      TSX     KML
# 98  2017-12-18 00:00:00  Delete  S&P/TSX Composite Index      TSX      JE
# 99  2017-12-18 00:00:00  Delete  S&P/TSX Composite Index      TSX     BNP
#
#                                                  name
# 0                      Summit Industrial Income REIT
# 1                                      Cargojet Inc.
# 2      Dream Industrial Real Estate Investment Trust
# 3                       Ag Growth International Inc.
# 4   NorthWest Healthcare Properties Real Estate In...
# 5                                   Ero Copper Corp.
# 6                      Computer Modelling Group Ltd.
# 7                       Kinder Morgan Canada Limited
# 8                               Lucara Diamond Corp.
# 9                      Summit Industrial Income REIT
# 10                                     Cargojet Inc.
# 11     Dream Industrial Real Estate Investment Trust
# 12                      Ag Growth International Inc.
# 13  NorthWest Healthcare Properties Real Estate In...
# 14                                  Ero Copper Corp.
# 15                     Summit Industrial Income REIT
# 16                                     Cargojet Inc.
# 17     Dream Industrial Real Estate Investment Trust
# 18                      Ag Growth International Inc.
# 19  NorthWest Healthcare Properties Real Estate In...
# 20                                  Ero Copper Corp.
# 21                     Summit Industrial Income REIT
# 22                                     Cargojet Inc.
# 23     Dream Industrial Real Estate Investment Trust
# 24                      Ag Growth International Inc.
# 25  NorthWest Healthcare Properties Real Estate In...
# 26                                  Ero Copper Corp.
# 27                     Summit Industrial Income REIT
# 28                                     Cargojet Inc.
# 29     Dream Industrial Real Estate Investment Trust
# ..                                                ...
# 70                            Guyana Goldfields Inc.
# 71                             Dorel Industries Inc.
# 72                                      Aritzia Inc.
# 73                                      Aritzia Inc.
# 74                                      Aritzia Inc.
# 75                                      Aritzia Inc.
# 76                                      Aritzia Inc.
# 77                                      Aritzia Inc.
# 78                                      Aritzia Inc.
# 79                                      Aritzia Inc.
# 80                                      Aritzia Inc.
# 81                Enbridge Income Fund Holdings Inc.
# 82                        Tamarack Valley Energy Ltd
# 83                               MTY Food Group Inc.
# 84            InterRent Real Estate Investment Trust
# 85                          Corus Entertainment Inc.
# 86                           Richelieu Hardware Ltd.
# 87                     Raging River Exploration Inc.
# 88                       Prometic Life Sciences Inc.
# 89    Choice Properties Real Estate Investment Trust
# 90                         Sienna Senior Living Inc.
# 91                              Aurora Cannabis Inc.
# 92                                  Crew Energy Inc.
# 93                              Chorus Aviation Inc.
# 94                                       Aphria Inc.
# 95     Killam Apartment Real Estate Investment Trust
# 96                        Canada Goose Holdings Inc.
# 97                      Kinder Morgan Canada Limited
# 98                            Just Energy Group Inc.
# 99                      Bonavista Energy Corporation
#
# [100 rows x 6 columns]

# %%
merged = changes.merge(holdings, on=['ticker','index','exchange'], how='outer', suffixes=('_chg','_hld'))
merged = merged.merge(all_mkt_cap[['date']], on=['date'], how='outer')
merged = merged[['date','action','ticker']].drop_duplicates()
#merged['action'].fillna('Add', inplace=True)

merged = merged.set_index(['date','ticker']).unstack()
merged = merged.replace('Delete',False).replace('Add',True)
merged = merged.fillna(method='ffill').fillna(False)

merged = merged.unstack().reset_index().drop(['level_0'],axis=1)
merged.columns = ['ticker','date','included']

merged = merged.loc[~merged['ticker'].isna()]
merged = merged.loc[~merged['date'].isna()]

merged = merged.merge(all_mkt_cap, on=['date','ticker'])
merged['contribution'] = merged['mkt_cap']*merged['included']

merged = merged.pivot_table(index=['date'], columns=['ticker'], values=['contribution'], aggfunc=np.sum)
index_cap = merged.sum(axis=1)

print(index_cap.head())
# Out:
# date
# 2010-01-04    0.0
# 2010-01-05    0.0
# 2010-01-06    0.0
# 2010-01-07    0.0
# 2010-01-08    0.0
# dtype: float64

# %%
index_cap
# Out:
# date
# 2010-01-04    0.000000e+00
# 2010-01-05    0.000000e+00
# 2010-01-06    0.000000e+00
# 2010-01-07    0.000000e+00
# 2010-01-08    0.000000e+00
# 2010-01-11    0.000000e+00
# 2010-01-12    0.000000e+00
# 2010-01-13    0.000000e+00
# 2010-01-14    0.000000e+00
# 2010-01-15    0.000000e+00
# 2010-01-18    0.000000e+00
# 2010-01-19    0.000000e+00
# 2010-01-20    0.000000e+00
# 2010-01-21    0.000000e+00
# 2010-01-22    0.000000e+00
# 2010-01-25    0.000000e+00
# 2010-01-26    0.000000e+00
# 2010-01-27    0.000000e+00
# 2010-01-28    0.000000e+00
# 2010-01-29    0.000000e+00
# 2010-02-01    0.000000e+00
# 2010-02-02    0.000000e+00
# 2010-02-03    0.000000e+00
# 2010-02-04    0.000000e+00
# 2010-02-05    0.000000e+00
# 2010-02-08    0.000000e+00
# 2010-02-09    0.000000e+00
# 2010-02-10    0.000000e+00
# 2010-02-11    0.000000e+00
# 2010-02-12    0.000000e+00
#                   ...
# 2018-05-18    1.384750e+10
# 2018-05-22    1.413700e+10
# 2018-05-23    1.424044e+10
# 2018-05-24    1.400203e+10
# 2018-05-25    1.381245e+10
# 2018-05-28    1.396284e+10
# 2018-05-29    1.396174e+10
# 2018-05-30    1.394507e+10
# 2018-05-31    1.426978e+10
# 2018-06-01    1.425600e+10
# 2018-06-04    1.445153e+10
# 2018-06-05    1.510163e+10
# 2018-06-06    1.624374e+10
# 2018-06-07    1.589116e+10
# 2018-06-08    1.558139e+10
# 2018-06-11    1.527838e+10
# 2018-06-12    1.541127e+10
# 2018-06-13    1.562647e+10
# 2018-06-14    1.571690e+10
# 2018-06-15    1.774150e+10
# 2018-06-18    1.869758e+10
# 2018-06-19    1.955951e+10
# 2018-06-20    1.952068e+10
# 2018-06-21    1.973248e+10
# 2018-06-22    1.857161e+10
# 2018-06-25    1.844446e+10
# 2018-06-26    1.797806e+10
# 2018-06-27    1.742848e+10
# 2018-06-28    1.801942e+10
# 2018-06-29    1.794964e+10
# Length: 2132, dtype: float64
