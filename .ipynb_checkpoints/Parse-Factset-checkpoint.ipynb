# %%
import pandas as pd, numpy as np
import os

directory = ['factset']
tables = {}

for file in os.listdir('//'.join(directory)):
    if '.xls' in file:
        file_path = '\\'.join(directory+[file])
        tables[file[:file.find('.')]] = pd.read_excel(file_path, skiprows=7)
#print(list(tables.keys()))

for table_name in tables.keys():
    print(table_name)
    if 'Key-Developments' in table_name:
        table = tables[table_name]
        drop_phrase = ' dropped from '
        add_phrase = ' added to '
        table['Index'] = table['Key Development Headline'].apply(lambda headline: 
                                                                 headline[headline.find(drop_phrase)-len(headline)+len(drop_phrase):] 
                                                                 if drop_phrase in headline 
                                                                 else headline[headline.find(add_phrase)-len(headline)+len(add_phrase):])
        table['Action'] = table['Action'].apply(lambda action: 'Delete' if 'Drop' in action else 'Add')
        table['Ticker_Pair'] = table['Company Name'].apply(lambda name: name[name.rfind('('):][1:-1])
        table['Ticker'] = table['Ticker_Pair'].apply(lambda ticker_pair: ticker_pair[:ticker_pair.find(':')])
        table['Exchange'] = table['Ticker_Pair'].apply(lambda ticker_pair: ticker_pair[ticker_pair.find(':')+1:])
        table['Name'] = table['Company Name'].apply(lambda name: name[:name.rfind('(')])
        table = table[['Key Developments By Date','Action','Index','Ticker','Exchange','Name']]
        table.columns = ['ticker','action','index','exchange','ticker','name']
        tables[table_name]=table
    elif 'Holdings' in table_name:
        table = tables[table_name]
        
        table['Ticker_Pair'] = table['Ticker']
        table['Exchange'] = table['Ticker_Pair'].apply(lambda ticker_pair: ticker_pair[:ticker_pair.find(':')])
        table['Ticker'] = table['Ticker_Pair'].apply(lambda ticker_pair: ticker_pair[ticker_pair.find(':')+1:])
        table = table[['Ticker','Exchange','Index Constituents']]
        
        split_indices = []
        for i, row in table.iterrows():
            indices = row['Index Constituents'].split('; ')
            if len(indices)>1:
                for index in indices:
                    working_row = row.copy(deep=True)
                    working_row['Index Constituents'] = index
                    split_indices.append(pd.DataFrame(working_row).T)
            else:
                split_indices.append(pd.DataFrame(row).T)
        table = pd.concat(split_indices)
        table = table.reset_index().drop(['index'],axis=1)
        #table.columns = ['ticker','exchange','index']
        tables[table_name]=table
    elif 'Sector' in table_name:
        table = tables[table_name]
        table['Ticker_Pair'] = table['Ticker']
        table['Exchange'] = table['Ticker_Pair'].apply(lambda ticker_pair: ticker_pair[:ticker_pair.find(':')]
                                                      if type(ticker_pair)==type('  ') else ticker_pair)
        table['Ticker'] = table['Ticker_Pair'].apply(lambda ticker_pair: ticker_pair[ticker_pair.find(':')+1:]
                                                      if type(ticker_pair)==type('  ') else ticker_pair)
        table.columns = ['ticker','share_type','name','industries','sector','comps','supls','industry','corp_type','exchange_name','ticker_pair','exchange']
        tables[table_name]=table
    else:
        table = tables[table_name]
        print(' > Unhandled table',table_name)
        break
# Out:
# All-Canadian-Index_Holdings
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-8112acbfd8da> in <module>
#      44                     working_row = row.copy(deep=True)
#      45                     working_row['Index Constituents'] = index
# ---> 46                     split_indices.append(pd.DataFrame(working_row).T)
#      47             else:
#      48                 split_indices.append(pd.DataFrame(row).T)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     418             elif getattr(data, 'name', None) is not None:
#     419                 mgr = init_dict({data.name: data}, index, columns,
# --> 420                                 dtype=dtype)
#     421             else:
#     422                 mgr = init_ndarray(data, index, columns, dtype=dtype,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     210         arrays = [data[k] for k in keys]
#     211
# --> 212     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     213
#     214
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      59     axes = [ensure_index(columns), index]
#      60
# ---> 61     return create_block_manager_from_arrays(arrays, arr_names, axes)
#      62
#      63
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_arrays(arrays, names, axes)
#    1664
#    1665     try:
# -> 1666         blocks = form_blocks(arrays, names, axes)
#    1667         mgr = BlockManager(blocks, axes)
#    1668         mgr._consolidate_inplace()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in form_blocks(arrays, names, axes)
#    1755         blocks.extend(object_blocks)
#    1756
# -> 1757     if len(items_dict['SparseBlock']) > 0:
#    1758         sparse_blocks = _sparse_blockify(items_dict['SparseBlock'])
#    1759         blocks.extend(sparse_blocks)
#
# KeyboardInterrupt:

# %%
table_clean = pd.read_excel('factset\\All-Canadian-Index_Ratios_1.xls', skiprows=7)
table = table_clean.copy(deep=True)

table = table.replace('-',np.nan)
table = table.replace('NM',np.nan)
columns = []
for column in table.columns:
    newcol = column
    if '%' in column:
        table[column]=table[column]/100
        column = column.replace('%','')
    if '[CQ' in column:
        date = column[column.find('[')+1:column.find(']')].split(' ')
        year=int(date[1])
        quarter=int(date[0][2:])
        
        factor = column[:column.find('[')]
        factors = factor.split(' ')
        factors = [for ]
        
        newcol = '_'.join([factor, str(year), 'Q', str(quarter)])
    newcol = newcol.replace(' ','')
    columns.append(newcol)
table.columns = columns

# %%
table
# Out:
#          Ticker                       SecurityName  ReturnonAssets_2010_Q_1  \
# 0       TSX:AAV                      Common Shares                  0.06490
# 1       TSX:ABT                      Common Shares                  0.00949
# 2       TSX:ABX                      Common Shares                  0.10300
# 3        TSX:AC  Voting and Variable Voting Shares                 -0.03720
# 4       TSX:ACB                      Common Shares                      NaN
# 5     TSX:ACO.X          Class I Non-Voting Shares                  0.07420
# 6       TSX:ACQ              Class A Common Shares                  0.03610
# 7        TSX:AD               Voting Common Shares                  0.04760
# 8       TSX:ADN                      Common Shares                  0.06480
# 9       TSX:AEM                      Common Shares                  0.03090
# 10      TSX:AFN                      Common Shares                  0.06200
# 11    TSX:AGF.B   Class B Non-Voting Common Shares                  0.03060
# 12      TSX:AGI                     Class A Shares                  0.03140
# 13      TSX:AGT                      Common Shares                  0.11600
# 14      TSX:AIF                      Common Shares                 -0.00458
# 15      TSX:AIM                       Common Stock                  0.01230
# 16      TSX:ALA                      Common Shares                  0.03990
# 17      TSX:ALO                      Common Shares                 -0.09960
# 18      TSX:ALS                      Common Shares                 -0.02920
# 19    TSX:AP.UN                        Trust Units                  0.05260
# 20     TSX:APHA                      Common Shares                      NaN
# 21   TSX:APR.UN                              Units                      NaN
# 22      TSX:APS                      Common Shares                 -0.96200
# 23      TSX:AQN                      Common Shares                  0.01410
# 24       TSX:AR                      Common Shares                      NaN
# 25      TSX:ARE                      Common Shares                 -0.02520
# 26      TSX:ARX                      Common Shares                  0.11000
# 27      TSX:ASR                      Common Shares                 -0.02950
# 28      TSX:ATA                      Common Shares                 -0.08060
# 29    TSX:ATD.B  Class B Subordinate Voting Shares                  0.06960
# ..          ...                                ...                      ...
# 797    TSXV:VIV                      Common Shares                 -2.29000
# 798   TSXV:VIVO                      Common Shares                      NaN
# 799    TSXV:VLC                      Common Shares                      NaN
# 800    TSXV:VML                      Common Shares                      NaN
# 801    TSXV:VPY                      Common Shares                 -0.86500
# 802    TSXV:VQS                      Common Shares                 -0.17000
# 803    TSXV:VRB                      Common Shares                 -0.12700
# 804    TSXV:VTT                       Common Stock                      NaN
# 805   TSXV:WAVE                      Common Shares                      NaN
# 806    TSXV:WED                      Common Shares                  0.00870
# 807    TSXV:WEE                      Common Shares                 -0.18900
# 808   TSXV:WELL                      Common Shares                      NaN
# 809    TSXV:WGO                      Common Shares                 -0.26900
# 810    TSXV:WHN                      Common Shares                      NaN
# 811    TSXV:WHY                      Common Shares                 -0.19600
# 812    TSXV:WIL                      Common Shares                 -0.05690
# 813    TSXV:WKM                      Common Shares                      NaN
# 814    TSXV:WLF                      Common Shares                      NaN
# 815    TSXV:WMD                      Common Shares                      NaN
# 816    TSXV:WML                      Common Shares                 -0.09820
# 817    TSXV:XBC                      Common Shares                 -0.37800
# 818    TSXV:XLY                      Common Shares                  0.17100
# 819     TSXV:XX                      Common Shares                 -0.03930
# 820    TSXV:YFI                      Common Shares                      NaN
# 821    TSXV:ZEN                      Common Shares                      NaN
# 822   TSXV:ZENA                       Common Stock                      NaN
# 823    TSXV:ZMS                      Common Shares                 -3.04600
# 824    TSXV:ZNX                      Common Shares                 -0.05370
# 825    TSXV:ZOM                       Common Stock                      NaN
# 826    TSXV:ZON                      Common Shares                      NaN
#
#      ReturnonAssets_2010_Q_2  ReturnonAssets_2010_Q_3  \
# 0                    0.00656                  0.01290
# 1                   -0.05400                 -0.05010
# 2                    0.09920                  0.10300
# 3                    0.00671                  0.06860
# 4                        NaN                      NaN
# 5                    0.04700                  0.04890
# 6                    0.05970                  0.03900
# 7                    0.04290                  0.04520
# 8                    0.00926                  0.05190
# 9                    0.05680                  0.05990
# 10                   0.13400                  0.15100
# 11                   0.02900                  0.03170
# 12                  -0.60300                  0.04000
# 13                   0.01420                  0.01670
# 14                   0.03340                  0.01470
# 15                   0.01010                  0.00872
# 16                   0.03760                  0.02090
# 17                   0.11500                  0.21700
# 18                  -0.00136                 -0.00462
# 19                   0.05000                  0.04990
# 20                       NaN                      NaN
# 21                       NaN                      NaN
# 22                  -1.32100                 -1.40900
# 23                   0.01440                  0.01220
# 24                   0.02510                  0.02830
# 25                   0.01510                  0.03210
# 26                   0.04560                  0.05500
# 27                  -0.04380                 -0.04390
# 28                   0.02730                  0.02070
# 29                   0.11900                  0.09850
# ..                       ...                      ...
# 797                 -2.02000                 -1.41300
# 798                      NaN                      NaN
# 799                      NaN                      NaN
# 800                      NaN                      NaN
# 801                 -0.44300                 -0.23700
# 802                 -0.16500                 -0.18500
# 803                 -0.26500                 -0.51100
# 804                      NaN                      NaN
# 805                      NaN                      NaN
# 806                  0.01540                  0.02230
# 807                 -0.11900                 -0.13000
# 808                      NaN                      NaN
# 809                 -0.65400                 -0.61700
# 810                      NaN                      NaN
# 811                 -0.56200                 -1.29100
# 812                 -0.15700                 -0.25800
# 813                 -0.24600                 -0.12100
# 814                      NaN                      NaN
# 815                      NaN                      NaN
# 816                 -0.09420                 -0.08040
# 817                 -0.38700                 -0.46100
# 818                  0.33000                  0.16000
# 819                 -0.18000                 -0.03430
# 820                      NaN                      NaN
# 821                      NaN                 -0.16200
# 822                      NaN                      NaN
# 823                 -6.07100                 -4.27800
# 824                 -0.04610                 -0.01520
# 825                      NaN                      NaN
# 826                 -0.75600                 -0.11300
#
#      ReturnonAssets_2010_Q_4  ReturnonAssets_2011_Q_1  \
# 0                   -0.02960                  0.00186
# 1                   -0.04240                  0.00124
# 2                    0.10700                  0.10700
# 3                    0.01030                 -0.01810
# 4                        NaN                      NaN
# 5                    0.06050                  0.07890
# 6                    0.03670                  0.04110
# 7                    0.03950                  0.04900
# 8                    0.06240                  0.06320
# 9                    0.05950                  0.04000
# 10                   0.04210                  0.06570
# 11                   0.03200                  0.01820
# 12                   0.07950                  0.07190
# 13                   0.01850                  0.05440
# 14                  -0.00577                  0.00596
# 15                   0.04260                  0.02500
# 16                   0.04090                  0.02290
# 17                   0.38000                  0.20000
# 18                  -0.04970                 -0.00847
# 19                   0.04400                  0.03230
# 20                       NaN                      NaN
# 21                       NaN                      NaN
# 22                  -1.21700                 -1.29900
# 23                   0.01880                  0.03050
# 24                   0.09420                  0.08520
# 25                  -0.02430                 -0.03860
# 26                  -0.01910                 -0.00203
# 27                  -0.03790                 -0.02760
# 28                   0.01930                  0.05070
# 29                   0.06410                  0.06080
# ..                       ...                      ...
# 797                 -1.42700                 -1.69800
# 798                      NaN                      NaN
# 799                      NaN                      NaN
# 800                      NaN                      NaN
# 801                 -0.25000                 -0.25200
# 802                 -0.20600                  0.39300
# 803                 -0.16900                 -0.13000
# 804                 -1.05700                 -0.16300
# 805                      NaN                      NaN
# 806                  0.01390                  0.01250
# 807                 -0.10400                 -0.06470
# 808                      NaN                      NaN
# 809                 -0.98000                 -1.18500
# 810                 -0.64800                 -0.06380
# 811                 -0.22000                 -0.12600
# 812                 -0.41400                 -0.12600
# 813                 -0.12200                 -0.08150
# 814                      NaN                      NaN
# 815                      NaN                      NaN
# 816                 -0.76700                 -0.22400
# 817                 -0.68500                 -0.03810
# 818                  0.29400                  0.11500
# 819                 -0.00904                 -0.28400
# 820                      NaN                      NaN
# 821                 -0.18500                 -0.08980
# 822                      NaN                      NaN
# 823                 -0.58500                 -0.90900
# 824                 -0.04490                 -0.02700
# 825                      NaN                      NaN
# 826                 -0.23700                 -0.43000
#
#      ReturnonAssets_2011_Q_2  ReturnonAssets_2011_Q_3  \
# 0                    0.01380                  0.00668
# 1                    0.02130                  0.01410
# 2                    0.10600                  0.11500
# 3                    0.01720                  0.06580
# 4                        NaN                      NaN
# 5                    0.05080                  0.05110
# 6                    0.08540                  0.07080
# 7                    0.31400                  0.04740
# 8                    0.00336                  0.03260
# 9                    0.05380                 -0.04890
# 10                   0.11600                  0.07870
# 11                   0.02130                  0.01620
# 12                       NaN                  0.01570
# 13                   0.02410                  0.05600
# 14                   0.01080                 -0.00016
# 15                   0.02370                  0.02920
# 16                   0.02760                  0.00170
# 17                   0.20900                  0.18300
# 18                   0.00306                 -0.00956
# 19                   0.03130                  0.03370
# 20                       NaN                      NaN
# 21                       NaN                      NaN
# 22                  -1.27700                 -1.52700
# 23                   0.03410                  0.02730
# 24                   0.06330                  0.07290
# 25                   0.00760                  0.05660
# 26                   0.10200                  0.09910
# 27                   0.06890                  0.09390
# 28                   0.03650                  0.04780
# 29                   0.11300                  0.09050
# ..                       ...                      ...
# 797                 -1.43600                 -2.39200
# 798                      NaN                      NaN
# 799                      NaN                      NaN
# 800                      NaN                      NaN
# 801                 -0.21000                  0.04580
# 802                 -0.06510                 -0.05590
# 803                 -0.18200                 -0.55000
# 804                 -0.73200                 -0.42200
# 805                      NaN                      NaN
# 806                      NaN                 -0.00398
# 807                 -0.07100                 -0.07650
# 808                      NaN                      NaN
# 809                 -0.82400                 -1.08100
# 810                 -0.07300                 -0.13200
# 811                 -0.67500                 -0.73200
# 812                 -0.25100                 -0.58000
# 813                 -0.08020                 -0.15000
# 814                      NaN                      NaN
# 815                      NaN                      NaN
# 816                 -0.59300                 -0.30200
# 817                 -0.18600                 -0.01310
# 818                  0.11300                  0.11700
# 819                 -0.24900                 -0.25900
# 820                      NaN                      NaN
# 821                 -0.10200                 -0.10600
# 822                      NaN                      NaN
# 823                 -1.69700                 -1.21900
# 824                 -0.02710                 -0.01180
# 825                      NaN                      NaN
# 826                 -0.46200                 -0.34300
#
#      ReturnonAssets_2011_Q_4  ...  EBITDA,1YrGrowth_2016_Q_3  \
# 0                   -0.23400  ...                     0.2660
# 1                    0.01800  ...                    -0.7100
# 2                    0.08840  ...                     0.3180
# 3                   -0.02690  ...                     0.1730
# 4                        NaN  ...                        NaN
# 5                    0.06670  ...                     0.2540
# 6                    0.06170  ...                    -0.1190
# 7                    0.05310  ...                     0.0563
# 8                    0.03230  ...                    -0.2160
# 9                   -0.39100  ...                     0.5260
# 10                   0.05260  ...                     3.3000
# 11                   0.01360  ...                    -0.3940
# 12                  -0.00148  ...                     1.9410
# 13                   0.00587  ...                     0.1710
# 14                   0.05290  ...                     0.4020
# 15                  -0.01470  ...                     0.5940
# 16                   0.04050  ...                     0.3210
# 17                       NaN  ...                        NaN
# 18                   0.03400  ...                     0.4430
# 19                   0.03830  ...                     0.0427
# 20                       NaN  ...                        NaN
# 21                       NaN  ...                        NaN
# 22                  -1.99100  ...                        NaN
# 23                       NaN  ...                     0.2870
# 24                   0.10000  ...                    16.6080
# 25                   0.06890  ...                    -0.2130
# 26                  -0.02960  ...                    -0.3690
# 27                   0.10400  ...                    -0.8580
# 28                   0.07140  ...                    -0.2880
# 29                   0.06720  ...                    -0.0417
# ..                       ...  ...                        ...
# 797                 -4.21600  ...                        NaN
# 798                      NaN  ...                        NaN
# 799                      NaN  ...                        NaN
# 800                      NaN  ...                        NaN
# 801                 -0.35900  ...                        NaN
# 802                 -0.18200  ...                        NaN
# 803                 -0.09460  ...                        NaN
# 804                 -0.60900  ...                        NaN
# 805                      NaN  ...                        NaN
# 806                 -0.00812  ...                        NaN
# 807                 -0.08120  ...                        NaN
# 808                      NaN  ...                        NaN
# 809                 -0.31100  ...                        NaN
# 810                 -0.14700  ...                        NaN
# 811                  0.35200  ...                        NaN
# 812                 -2.01200  ...                        NaN
# 813                 -0.53000  ...                        NaN
# 814                      NaN  ...                        NaN
# 815                      NaN  ...                        NaN
# 816                 -0.37700  ...                        NaN
# 817                 -0.36500  ...                        NaN
# 818                  0.23600  ...                        NaN
# 819                 -0.04320  ...                     0.0425
# 820                 -0.67100  ...                        NaN
# 821                 -0.07790  ...                        NaN
# 822                      NaN  ...                        NaN
# 823                 -2.21500  ...                        NaN
# 824                 -0.01430  ...                        NaN
# 825                      NaN  ...                        NaN
# 826                 -0.34800  ...                        NaN
#
#      EBITDA,1YrGrowth_2016_Q_4  EBITDA,1YrGrowth_2017_Q_1  \
# 0                      -0.5220                     0.8680
# 1                       1.6330                     1.8840
# 2                       3.1500                     0.0395
# 3                      -0.1490                    -0.3110
# 4                          NaN                        NaN
# 5                       0.5030                     0.0335
# 6                      -0.1080                    -0.0012
# 7                       0.2330                    -0.5430
# 8                      -0.0500                     0.0837
# 9                       0.2960                     0.2860
# 10                      2.2570                     0.2680
# 11                         NaN                    -0.0470
# 12                      0.2810                     0.1720
# 13                      0.1400                    -0.3670
# 14                      0.3480                     0.1640
# 15                         NaN                    -0.0617
# 16                     -0.1420                     0.1100
# 17                     -0.8040                     0.4390
# 18                      2.0250                    52.1000
# 19                      0.0942                     0.0762
# 20                         NaN                        NaN
# 21                     -0.5050                     0.1310
# 22                         NaN                        NaN
# 23                      0.2700                     0.7750
# 24                      5.2620                    -0.0122
# 25                      0.1040                     2.6290
# 26                     -0.5020                     1.0840
# 27                     -0.4570                    -0.0110
# 28                     -0.3280                     0.0962
# 29                      0.0446                     0.1000
# ..                         ...                        ...
# 797                        NaN                        NaN
# 798                        NaN                        NaN
# 799                        NaN                        NaN
# 800                        NaN                        NaN
# 801                        NaN                        NaN
# 802                        NaN                        NaN
# 803                        NaN                        NaN
# 804                        NaN                        NaN
# 805                        NaN                        NaN
# 806                        NaN                    -0.0073
# 807                        NaN                        NaN
# 808                        NaN                        NaN
# 809                        NaN                        NaN
# 810                        NaN                        NaN
# 811                        NaN                        NaN
# 812                        NaN                        NaN
# 813                        NaN                        NaN
# 814                        NaN                        NaN
# 815                        NaN                        NaN
# 816                        NaN                        NaN
# 817                        NaN                        NaN
# 818                        NaN                        NaN
# 819                     0.5940                    -0.4270
# 820                        NaN                        NaN
# 821                        NaN                        NaN
# 822                        NaN                        NaN
# 823                        NaN                        NaN
# 824                        NaN                        NaN
# 825                        NaN                        NaN
# 826                        NaN                        NaN
#
#      EBITDA,1YrGrowth_2017_Q_2  EBITDA,1YrGrowth_2017_Q_3  \
# 0                          NaN                     0.0739
# 1                       0.0610                     1.8870
# 2                       0.2080                    -0.2510
# 3                       0.1240                     0.0941
# 4                          NaN                        NaN
# 5                      -0.0619                    -0.1020
# 6                       0.4160                     0.1570
# 7                      -0.0697                     1.1660
# 8                      -0.4960                     0.2470
# 9                       0.0152                    -0.0691
# 10                      0.5800                    -0.0348
# 11                      0.1200                     0.2570
# 12                      0.2630                     0.0911
# 13                     -0.3460                    -0.7430
# 14                      0.3090                     0.0247
# 15                     -0.5750                     0.1950
# 16                      0.0280                    -0.1530
# 17                     -0.3280                    -0.7800
# 18                      1.8830                     3.0450
# 19                      0.0846                     0.1090
# 20                      6.0950                     0.6170
# 21                      0.2630                     0.2420
# 22                         NaN                        NaN
# 23                      0.8140                     1.2850
# 24                      0.1350                    -0.3540
# 25                     -0.1530                    -0.0137
# 26                     18.0510                    -0.0515
# 27                      0.2370                     5.7750
# 28                     -0.0431                     0.3020
# 29                      0.1680                     0.3480
# ..                         ...                        ...
# 797                        NaN                        NaN
# 798                        NaN                        NaN
# 799                        NaN                        NaN
# 800                        NaN                        NaN
# 801                        NaN                        NaN
# 802                        NaN                        NaN
# 803                        NaN                        NaN
# 804                        NaN                        NaN
# 805                        NaN                        NaN
# 806                        NaN                        NaN
# 807                        NaN                        NaN
# 808                        NaN                        NaN
# 809                        NaN                        NaN
# 810                        NaN                        NaN
# 811                        NaN                        NaN
# 812                        NaN                        NaN
# 813                        NaN                        NaN
# 814                        NaN                        NaN
# 815                        NaN                        NaN
# 816                        NaN                        NaN
# 817                        NaN                        NaN
# 818                        NaN                        NaN
# 819                    -0.0547                     0.2900
# 820                        NaN                        NaN
# 821                        NaN                        NaN
# 822                        NaN                        NaN
# 823                        NaN                        NaN
# 824                        NaN                        NaN
# 825                        NaN                        NaN
# 826                        NaN                        NaN
#
#      EBITDA,1YrGrowth_2017_Q_4  EBITDA,1YrGrowth_2018_Q_1  \
# 0                       2.3380                    -0.5050
# 1                       0.5680                     0.1800
# 2                      -0.0260                    -0.0738
# 3                       0.2330                     0.1370
# 4                          NaN                        NaN
# 5                       0.0248                    -0.0152
# 6                      -0.4390                    -0.2760
# 7                      -0.2480                        NaN
# 8                      -0.1970                     0.1870
# 9                      -0.1820                    -0.1340
# 10                      0.4320                     0.2730
# 11                         NaN                    -0.0332
# 12                      0.6820                     0.9800
# 13                     -0.8450                    -0.2430
# 14                     -0.1540                     0.2130
# 15                         NaN                     0.8680
# 16                      0.1770                    -0.0131
# 17                     -0.9560                    -0.4480
# 18                         NaN                        NaN
# 19                      0.0662                     0.1080
# 20                         NaN                        NaN
# 21                      0.2280                     0.1620
# 22                         NaN                        NaN
# 23                      0.7220                     0.0516
# 24                      0.2160                     0.6730
# 25                     -0.1060                        NaN
# 26                      1.1730                    -0.4520
# 27                      4.7350                     1.2750
# 28                      0.2540                     0.4600
# 29                      0.1510                     0.3360
# ..                         ...                        ...
# 797                        NaN                        NaN
# 798                        NaN                        NaN
# 799                        NaN                        NaN
# 800                        NaN                        NaN
# 801                        NaN                        NaN
# 802                        NaN                        NaN
# 803                        NaN                        NaN
# 804                        NaN                        NaN
# 805                        NaN                        NaN
# 806                        NaN                     0.8660
# 807                        NaN                        NaN
# 808                        NaN                        NaN
# 809                        NaN                        NaN
# 810                        NaN                        NaN
# 811                        NaN                        NaN
# 812                        NaN                        NaN
# 813                        NaN                        NaN
# 814                        NaN                        NaN
# 815                        NaN                        NaN
# 816                        NaN                        NaN
# 817                        NaN                        NaN
# 818                        NaN                        NaN
# 819                    -0.1140                     2.5190
# 820                        NaN                        NaN
# 821                        NaN                        NaN
# 822                        NaN                        NaN
# 823                        NaN                        NaN
# 824                        NaN                        NaN
# 825                        NaN                        NaN
# 826                        NaN                        NaN
#
#      EBITDA,1YrGrowth_2018_Q_2  EBITDA,1YrGrowth_2018_Q_3  \
# 0                      -0.8720                   -0.50200
# 1                       1.3400                    0.85000
# 2                      -0.4050                   -0.19900
# 3                      -0.0476                   -0.08600
# 4                          NaN                        NaN
# 5                      -0.1820                    0.30100
# 6                      -0.5360                   -0.49100
# 7                       0.3680                   -0.43300
# 8                       0.3800                   -0.12800
# 9                      -0.1990                   -0.27700
# 10                      0.1760                    0.43100
# 11                     -0.2310                    0.18900
# 12                      0.1900                   -0.17300
# 13                     -0.0813                    0.83900
# 14                     -0.0578                   -0.31100
# 15                      2.9710                    0.29000
# 16                      0.0875                    0.28200
# 17                      0.1850                    0.23900
# 18                         NaN                        NaN
# 19                      0.0742                    0.07300
# 20                     -0.8670                        NaN
# 21                      0.0705                    0.10700
# 22                         NaN                        NaN
# 23                      0.1070                    0.00808
# 24                      0.4550                   -0.68500
# 25                      0.3410                    0.55200
# 26                     -0.4550                    0.20500
# 27                      0.1680                   -0.30800
# 28                      0.2220                   -0.08980
# 29                      0.2780                    0.02590
# ..                         ...                        ...
# 797                        NaN                        NaN
# 798                        NaN                        NaN
# 799                        NaN                        NaN
# 800                        NaN                        NaN
# 801                        NaN                        NaN
# 802                        NaN                        NaN
# 803                        NaN                        NaN
# 804                        NaN                        NaN
# 805                        NaN                        NaN
# 806                     2.0900                    0.21500
# 807                        NaN                        NaN
# 808                        NaN                        NaN
# 809                        NaN                        NaN
# 810                        NaN                        NaN
# 811                        NaN                        NaN
# 812                        NaN                        NaN
# 813                        NaN                        NaN
# 814                        NaN                        NaN
# 815                        NaN                        NaN
# 816                        NaN                        NaN
# 817                    -0.2320                    3.39000
# 818                        NaN                        NaN
# 819                    -0.8310                   -0.95300
# 820                        NaN                        NaN
# 821                        NaN                        NaN
# 822                        NaN                        NaN
# 823                        NaN                        NaN
# 824                        NaN                        NaN
# 825                        NaN                        NaN
# 826                        NaN                        NaN
#
#      EBITDA,1YrGrowth_2018_Q_4
# 0                       0.1360
# 1                       0.2980
# 2                      -0.2470
# 3                       0.0599
# 4                          NaN
# 5                      -0.0786
# 6                      -0.0226
# 7                       0.0918
# 8                      -0.1690
# 9                      -0.1770
# 10                     -0.1080
# 11                         NaN
# 12                     -0.0584
# 13                      2.9530
# 14                     -0.4510
# 15                         NaN
# 16                      1.0830
# 17                         NaN
# 18                         NaN
# 19                      0.0709
# 20                         NaN
# 21                      0.2530
# 22                         NaN
# 23                      0.0308
# 24                         NaN
# 25                      0.2300
# 26                      0.4770
# 27                     -0.4720
# 28                      0.5440
# 29                      0.5600
# ..                         ...
# 797                        NaN
# 798                        NaN
# 799                        NaN
# 800                        NaN
# 801                        NaN
# 802                        NaN
# 803                        NaN
# 804                        NaN
# 805                        NaN
# 806                    -0.6200
# 807                        NaN
# 808                        NaN
# 809                        NaN
# 810                        NaN
# 811                        NaN
# 812                        NaN
# 813                        NaN
# 814                        NaN
# 815                        NaN
# 816                        NaN
# 817                        NaN
# 818                        NaN
# 819                        NaN
# 820                        NaN
# 821                        NaN
# 822                        NaN
# 823                        NaN
# 824                        NaN
# 825                        NaN
# 826                        NaN
#
# [827 rows x 254 columns]

# %%
table.columns
